# %%
import re
import pandas as pd

# %%
f=open("WhatsApp Chat with मित्र मण्डली.txt",'r',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)
# Out:
# 07/05/20, 20:31 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 18/11/17, 21:55 - Kos created group "मित्र मण्डली"
# 07/05/20, 20:29 - Sandy 1 added you
# 07/05/20, 20:31 - ⛰️: Bc
# 07/05/20, 20:34 - Kos: Kahan chala gaya tha???
# 07/05/20, 20:34 - ⛰️: Are bhai yo sandy ne mere mobile se kar diya
# 07/05/20, 20:34 - ⛰️: Mujhe to Abhi pata chala
# 07/05/20, 20:36 - Sandy 1: Bkl
# 07/05/20, 20:36 - Sandy 1: Mne to add kiya h teko
# 07/05/20, 20:36 - Sandy 1: Sale
# 07/05/20, 20:37 - Sandy 1: Bhosdk
# 07/05/20, 20:37 - Sandy 1: 😡
# 07/05/20, 20:37 - Kos: Bahana to dhang ka marta jp
# 07/05/20, 20:37 - Kos: 😂
# 07/05/20, 20:37 - Sandy 1: Ye bc
# 07/05/20, 21:45 - Satpal Tc: <Media omitted>
# 07/05/20, 21:47 - Anil: 🤣🤣🤣
# 07/05/20, 21:51 - ⛰️: Sach bhai ye sala sandy gandu h
# 07/05/20, 21:51 - Sandy 1: Ht bc
# 07/05/20, 21:51 - Sandy 1: Abhi sale ko
# 07/05/20, 21:51 - Sandy 1: Bhr krdunga
# ...

# %%
#regular expression string by using regex 101 tool

# %%
 pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern, data)[1:]
len(messages)
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Kos created group "मित्र मण्डली"\n',
#  'Sandy 1 added you\n',
#  '⛰️: Bc\n',
#  'Kos: Kahan chala gaya tha???\n',
#  '⛰️: Are bhai yo sandy ne mere mobile se kar diya\n',
#  '⛰️: Mujhe to Abhi pata chala\n',
#  'Sandy 1: Bkl\n',
#  'Sandy 1: Mne to add kiya h teko\n',
#  'Sandy 1: Sale\n',
#  'Sandy 1: Bhosdk\n',
#  'Sandy 1: 😡\n',
#  'Kos: Bahana to dhang ka marta jp\n',
#  'Kos: 😂\n',
#  'Sandy 1: Ye bc\n',
#  'Satpal Tc: <Media omitted>\n',
#  'Anil: 🤣🤣🤣\n',
#  '⛰️: Sach bhai ye sala sandy gandu h\n',
#  'Sandy 1: Ht bc\n',
#  'Sandy 1: Abhi sale ko\n',
#  'Sandy 1: Bhr krdunga\n',
#  'Sandy 1: Grp se\n',
#  'Sandy 1: 🤣\n',
#  '⛰️: Chut mar lunga teri\n',
#  'Sandy 1: Ht bc\n',
#  'Satpal Tc: Sach humesa kadva hota h par sach toh sach h bhai\n',
#  '⛰️: Sala dohra game khel gaya sattu\n',
#  'Lala1: Ye sach lg rha h\n',
# ...

# %%
dates = re.findall(pattern, data)
dates
# Out:
# ['07/05/20, 20:31 - ',
#  '18/11/17, 21:55 - ',
#  '07/05/20, 20:29 - ',
#  '07/05/20, 20:31 - ',
#  '07/05/20, 20:34 - ',
#  '07/05/20, 20:34 - ',
#  '07/05/20, 20:34 - ',
#  '07/05/20, 20:36 - ',
#  '07/05/20, 20:36 - ',
#  '07/05/20, 20:36 - ',
#  '07/05/20, 20:37 - ',
#  '07/05/20, 20:37 - ',
#  '07/05/20, 20:37 - ',
#  '07/05/20, 20:37 - ',
#  '07/05/20, 20:37 - ',
#  '07/05/20, 21:45 - ',
#  '07/05/20, 21:47 - ',
#  '07/05/20, 21:51 - ',
#  '07/05/20, 21:51 - ',
#  '07/05/20, 21:51 - ',
#  '07/05/20, 21:51 - ',
#  '07/05/20, 21:51 - ',
#  '07/05/20, 21:51 - ',
#  '07/05/20, 21:52 - ',
#  '07/05/20, 21:52 - ',
#  '07/05/20, 21:53 - ',
#  '07/05/20, 21:54 - ',
#  '07/05/20, 22:35 - ',
#  '07/05/20, 22:36 - ',
#  '07/05/20, 22:36 - ',
#  '08/05/20, 09:09 - ',
#  '08/05/20, 17:36 - ',
#  '08/05/20, 17:40 - ',
#  '09/05/20, 12:23 - ',
#  '09/05/20, 12:23 - ',
#  '09/05/20, 12:23 - ',
#  '09/05/20, 12:47 - ',
#  '09/05/20, 12:47 - ',
#  '09/05/20, 12:47 - ',
#  '09/05/20, 12:47 - ',
# ...

# %%
from datetime import datetime
df = pd.DataFrame({'user_message': messages, 'message_date': dates})

# convert message_date type

df['message_date'] = pd.to_datetime(df['message_date'],format='%d/%m/%y, %H:%M - ')

df.rename(columns={'message_date': 'date'}, inplace=True)
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2020-05-07 20:31:00
# 1                 Kos created group "मित्र मण्डली"\n 2017-11-18 21:55:00
# 2                                Sandy 1 added you\n 2020-05-07 20:29:00
# 3                                           ⛰️: Bc\n 2020-05-07 20:31:00
# 4                     Kos: Kahan chala gaya tha???\n 2020-05-07 20:34:00

# %%
df.shape
# Out:
# (5667, 2)

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])
        
df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1                 Kos created group "मित्र मण्डली"\n
# 2                                Sandy 1 added you\n
# 3                                               Bc\n
# 4                          Kahan chala gaya tha???\n

# %%
 df['only_date'] = df['date'].dt.date

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18
# 2                                Sandy 1 added you\n  2020-05-07
# 3                                               Bc\n  2020-05-07
# 4                          Kahan chala gaya tha???\n  2020-05-07

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020

# %%
df['month_num'] = df['date'].dt.month

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num
# 0          5
# 1         11
# 2          5
# 3          5
# 4          5

# %%
df['month'] = df['date'].dt.month_name()

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month
# 0          5       May
# 1         11  November
# 2          5       May
# 3          5       May
# 4          5       May

# %%
df['day'] = df['date'].dt.day

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month  day
# 0          5       May    7
# 1         11  November   18
# 2          5       May    7
# 3          5       May    7
# 4          5       May    7

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month  day  day_name
# 0          5       May    7  Thursday
# 1         11  November   18  Saturday
# 2          5       May    7  Thursday
# 3          5       May    7  Thursday
# 4          5       May    7  Thursday

# %%
df['hour'] = df['date'].dt.hour

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month  day  day_name  hour
# 0          5       May    7  Thursday    20
# 1         11  November   18  Saturday    21
# 2          5       May    7  Thursday    20
# 3          5       May    7  Thursday    20
# 4          5       May    7  Thursday    20

# %%
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month  day  day_name  hour  minute
# 0          5       May    7  Thursday    20      31
# 1         11  November   18  Saturday    21      55
# 2          5       May    7  Thursday    20      29
# 3          5       May    7  Thursday    20      31
# ...

# %%
df[df['user']== 'Sandy1'].shape
# Out:
# (0, 11)

# %%
for message in df['message']:
    print(message)
# Out:
# Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
#
# Kos created group "मित्र मण्डली"
#
# Sandy 1 added you
#
# Bc
#
# Kahan chala gaya tha???
#
# Are bhai yo sandy ne mere mobile se kar diya
#
# Mujhe to Abhi pata chala
#
# Bkl
#
# Mne to add kiya h teko
#
# Sale
#
# Bhosdk
#
# 😡
#
# Bahana to dhang ka marta jp
#
# 😂
#
# Ye bc
#
# <Media omitted>
#
# 🤣🤣🤣
#
# Sach bhai ye sala sandy gandu h
#
# Ht bc
#
# Abhi sale ko
#
# Bhr krdunga
#
# Grp se
#
# 🤣
#
# Chut mar lunga teri
#
# Ht bc
#
# Sach humesa kadva hota h par sach toh sach h bhai
#
# Sala dohra game khel gaya sattu
#
# Ye sach lg rha h
#
# Sach hi h
#
# Thik
#
# <Media omitted>
#
# This message was deleted
#
# <Media omitted>
#
# मातृभूमि की स्वाधीनता के लिए अपना संपूर्ण जीवन बलिदान करने वाले त्याग, और पराक्रम के प्रतीक,मेवाड़ के स्वाभिमानी वीर शिरोमणि महाराणा प्रताप जी की जयंती पर उन्हें मेरा कोटि कोटि नमन एवं श्रद्धांजलि 🙏🙏
# ...

# %%
words=[]
for message in df['message']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 30582

# %%
# one best libray named urlextract used for extractinf links

# %%
df
# Out:
#                     date                user  \
# 0    2020-05-07 20:31:00  group_notification
# 1    2017-11-18 21:55:00  group_notification
# 2    2020-05-07 20:29:00  group_notification
# 3    2020-05-07 20:31:00                  ⛰️
# 4    2020-05-07 20:34:00                 Kos
# ...                  ...                 ...
# 5662 2022-08-11 00:26:00                  ⛰️
# 5663 2022-08-11 12:23:00                Anil
# 5664 2022-08-11 12:26:00                 Kos
# 5665 2022-08-11 12:27:00                 Kos
# 5666 2022-08-11 12:27:00                Anil
#
#                                                 message   only_date  year  \
# 0     Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                    Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                   Sandy 1 added you\n  2020-05-07  2020
# 3                                                  Bc\n  2020-05-07  2020
# ...

# %%
df['user'].value_counts()
# Out:
# ⛰️                    1107
# Su&1                  1102
# Sandy 1                970
# Lala1                  746
# Kos                    678
# Anil                   563
# Satpal Tc              376
# Sachin Tanwar MBBS      59
# +962 7 9728 3746        27
# group_notification      20
# Vivek Pandey            19
# Name: user, dtype: int64

# %%
x=df['user'].value_counts().head()
x
# Out:
# ⛰️         1107
# Su&1       1102
# Sandy 1     970
# Lala1       746
# Kos         678
# Name: user, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
name=x.index
count=x.values

# %%
plt.bar(name,count)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\jp215\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9968 (\N{MOUNTAIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['user'].value_counts()
# Out:
# ⛰️                    1107
# Su&1                  1102
# Sandy 1                970
# Lala1                  746
# Kos                    678
# Anil                   563
# Satpal Tc              376
# Sachin Tanwar MBBS      59
# +962 7 9728 3746        27
# group_notification      20
# Vivek Pandey            19
# Name: user, dtype: int64

# %%
df['user'].value_counts()/df.shape[0]
# Out:
# ⛰️                    0.195341
# Su&1                  0.194459
# Sandy 1               0.171166
# Lala1                 0.131639
# Kos                   0.119640
# Anil                  0.099347
# Satpal Tc             0.066349
# Sachin Tanwar MBBS    0.010411
# +962 7 9728 3746      0.004764
# group_notification    0.003529
# Vivek Pandey          0.003353
# Name: user, dtype: float64

# %%
(df['user'].value_counts()/df.shape[0])*100
# Out:
# ⛰️                    19.534145
# Su&1                  19.445915
# Sandy 1               17.116640
# Lala1                 13.163932
# Kos                   11.964002
# Anil                   9.934710
# Satpal Tc              6.634904
# Sachin Tanwar MBBS     1.041115
# +962 7 9728 3746       0.476443
# group_notification     0.352920
# Vivek Pandey           0.335274
# Name: user, dtype: float64

# %%
round((df['user'].value_counts()/df.shape[0])*100,2)
# Out:
# ⛰️                    19.53
# Su&1                  19.45
# Sandy 1               17.12
# Lala1                 13.16
# Kos                   11.96
# Anil                   9.93
# Satpal Tc              6.63
# Sachin Tanwar MBBS     1.04
# +962 7 9728 3746       0.48
# group_notification     0.35
# Vivek Pandey           0.34
# Name: user, dtype: float64

# %%
round((df['user'].value_counts()/df.shape[0])*100,2).reset_index()
# Out:
#                  index   user
# 0                   ⛰️  19.53
# 1                 Su&1  19.45
# 2              Sandy 1  17.12
# 3                Lala1  13.16
# 4                  Kos  11.96
# 5                 Anil   9.93
# 6            Satpal Tc   6.63
# 7   Sachin Tanwar MBBS   1.04
# 8     +962 7 9728 3746   0.48
# 9   group_notification   0.35
# 10        Vivek Pandey   0.34

# %%
round((df['user'].value_counts()/df.shape[0])*100,2).reset_index().rename(columns={'index':"name","user":"percent"})
# Out:
#                   name  percent
# 0                   ⛰️    19.53
# 1                 Su&1    19.45
# 2              Sandy 1    17.12
# 3                Lala1    13.16
# 4                  Kos    11.96
# 5                 Anil     9.93
# 6            Satpal Tc     6.63
# 7   Sachin Tanwar MBBS     1.04
# 8     +962 7 9728 3746     0.48
# 9   group_notification     0.35
# 10        Vivek Pandey     0.34

# %%
words=[]
for message in df['message']:
    words.extend(message.split())    #extend is used to append

# %%
words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'Kos',
#  'created',
#  'group',
#  '"मित्र',
#  'मण्डली"',
#  'Sandy',
#  '1',
#  'added',
#  'you',
#  'Bc',
#  'Kahan',
#  'chala',
#  'gaya',
#  'tha???',
#  'Are',
#  'bhai',
#  'yo',
#  'sandy',
#  'ne',
#  'mere',
#  'mobile',
#  'se',
#  'kar',
#  'diya',
#  'Mujhe',
#  'to',
#  'Abhi',
#  'pata',
#  'chala',
#  'Bkl',
#  'Mne',
#  'to',
#  'add',
#  'kiya',
#  'h',
#  'teko',
#  'Sale',
#  'Bhosdk',
#  '😡',
#  'Bahana',
#  'to',
#  'dhang',
#  'ka',
#  'marta',
#  'jp',
#  '😂',
#  'Ye',
#  'bc',
#  '<Media',
#  'omitted>',
#  '🤣🤣🤣',
#  'Sach',
#  'bhai',
#  'ye',
#  'sala',
#  'sandy',
#  'gandu',
#  'h',
#  'Ht',
#  'bc',
#  'Abhi',
#  'sale',
#  'ko',
#  'Bhr',
#  'krdunga',
#  'Grp',
# ...

# %%
from collections import Counter
Counter(words)    # Counter is used to find frequency
# Out:
# Counter({'Messages': 1,
#          'and': 51,
#          'calls': 1,
#          'are': 10,
#          'end-to-end': 1,
#          'encrypted.': 1,
#          'No': 6,
#          'one': 5,
#          'outside': 1,
#          'of': 25,
#          'this': 27,
#          'chat,': 1,
#          'not': 10,
#          'even': 2,
#          'WhatsApp,': 1,
#          'can': 8,
#          'read': 2,
#          'or': 14,
#          'listen': 1,
#          'to': 366,
#          'them.': 1,
#          'Tap': 11,
#          'learn': 12,
#          'more.': 11,
#          'Kos': 18,
#          'created': 1,
#          'group': 16,
#          '"मित्र': 1,
#          'मण्डली"': 1,
#          'Sandy': 14,
#          '1': 31,
#          'added': 2,
#          'you': 44,
#          'Bc': 57,
#          'Kahan': 12,
#          'chala': 8,
#          'gaya': 22,
#          'tha???': 1,
#          'Are': 35,
#          'bhai': 326,
#          'yo': 5,
#          'sandy': 12,
#          'ne': 39,
# ...

# %%
Counter(words).most_common(20)
# Out:
# [('<Media', 832),
#  ('omitted>', 832),
#  ('h', 717),
#  ('to', 366),
#  ('bhai', 326),
#  ('Bhai', 210),
#  ('के', 198),
#  ('nhi', 197),
#  ('ho', 177),
#  ('😂', 172),
#  ('ki', 163),
#  ('me', 162),
#  ('ko', 159),
#  ('में', 158),
#  ('bhi', 154),
#  ('k', 151),
#  ('hai', 148),
#  ('se', 147),
#  ('से', 147),
#  ('ka', 145)]

# %%
pd.DataFrame(Counter(words).most_common(20))
# Out:
#            0    1
# 0     <Media  832
# 1   omitted>  832
# 2          h  717
# 3         to  366
# 4       bhai  326
# 5       Bhai  210
# 6         के  198
# 7        nhi  197
# 8         ho  177
# 9          😂  172
# 10        ki  163
# 11        me  162
# 12        ko  159
# 13       में  158
# 14       bhi  154
# 15         k  151
# 16       hai  148
# 17        se  147
# 18        से  147
# 19        ka  145

# %%
#remove group messages
#and remove media omitted messages

# %%
temp=df[df['user'] != 'group_noticification']

# %%
temp=temp[temp['message'] != "<Media omitted>\n"]

# %%
f=open("stop_hinglish.txt",'r')
stop_words=f.read()
print(stop_words)
# Out:
# .
# ..
# ...
# ?
# -
# --
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0
# a
# aadi
# aaj
# aap
# aapne
# aata
# aati
# aaya
# aaye
# ab
# abbe
# abbey
# abe
# abhi
# able
# about
# above
# accha
# according
# accordingly
# acha
# achcha
# across
# actually
# after
# afterwards
# again
# against
# agar
# ain
# aint
# ain't
# aisa
# aise
# aisi
# alag
# all
# allow
# allows
# almost
# alone
# along
# already
# also
# although
# always
# am
# among
# amongst
# an
# and
# andar
# another
# any
# anybody
# anyhow
# anyone
# anything
# anyway
# anyways
# anywhere
# ap
# apan
# apart
# apna
# apnaa
# apne
# apni
# appear
# are
# aren
# arent
# aren't
# around
# arre
# as
# aside
# ask
# asking
# at
# aur
# avum
# aya
# aye
# baad
# baar
# bad
# bahut
# bana
# banae
# banai
# banao
# banaya
# banaye
# banayi
# banda
# bande
# bandi
# bane
# bani
# bas
# bata
# batao
# bc
# be
# became
# because
# become
# becomes
# becoming
# been
# before
# beforehand
# behind
# being
# below
# beside
# besides
# ...

# %%
words=[]
for message in temp['message']:
    for word in message.lower().split():
        if word not in stop_words:
            words.append(word)

# %%
from collections import Counter
pd.DataFrame(Counter(words).most_common(20))
# Out:
#           0    1
# 0        के  198
# 1         😂  172
# 2       में  158
# 3        से  147
# 4        jp  126
# 5        की  119
# 6        को  118
# 7     happy  113
# 8        तो  110
# 9        है  101
# 10       hn   87
# 11       का   86
# 12       और   83
# 13       😂😂   72
# 14       एक   67
# 15     नहीं   67
# 16  bhiwani   67
# 17       पर   65
# 18       ने   64
# 19       भी   62

# %%
# !pip install emoji
# Out:
# ...
#   Created wheel for emoji: filename=emoji-2.0.0-py3-none-any.whl size=193022 sha256=a444fef8dc0134236c67fe6ff73c75bdc8eb01e06ff35890c5da369307cc15d9
#   Stored in directory: c:\users\jp215\appdata\local\pip\cache\wheels\0e\d1\c5\63b511b700c9da5a62bbfc758dd4a3fd9541df51b5db0694b0
# Successfully built emoji
# ...

# %%
import emoji

# %%
emojis=[]
for message in df['message']:
    emojis.extend([c for c in message if c in emoji.EMOJI_DATA])

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
#      0     1
# 0    😂  1096
# 1    🤣   625
# 2    🙏   105
# 3    😅   101
# 4    🏻    98
# ..  ..   ...
# 110  🎄     1
# 111  🎃     1
# 112  💄     1
# 113  🏃     1
# 114  👆     1
#
# [115 rows x 2 columns]

# %%
df['month_num']=df['date'].dt.month

# %%
df
# Out:
#                     date                user  \
# 0    2020-05-07 20:31:00  group_notification
# 1    2017-11-18 21:55:00  group_notification
# 2    2020-05-07 20:29:00  group_notification
# 3    2020-05-07 20:31:00                  ⛰️
# 4    2020-05-07 20:34:00                 Kos
# ...                  ...                 ...
# 5662 2022-08-11 00:26:00                  ⛰️
# 5663 2022-08-11 12:23:00                Anil
# 5664 2022-08-11 12:26:00                 Kos
# 5665 2022-08-11 12:27:00                 Kos
# 5666 2022-08-11 12:27:00                Anil
#
#                                                 message   only_date  year  \
# 0     Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                    Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                   Sandy 1 added you\n  2020-05-07  2020
# 3                                                  Bc\n  2020-05-07  2020
# ...

# %%
df.groupby(['year','month_num','month']).count()['message']
# Out:
# year  month_num  month
# 2017  11         November       1
# 2020  5          May          575
#       6          June         742
#       7          July         214
#       8          August        93
#       9          September    213
#       10         October      471
#       11         November     484
#       12         December     143
# 2021  1          January      395
#       2          February     106
#       3          March        117
#       4          April        202
#       5          May          158
#       6          June          20
#       7          July          40
#       8          August       102
#       9          September     44
#       10         October      167
#       11         November     444
#       12         December      92
# 2022  1          January       69
#       2          February     226
#       3          March        349
#       4          April         64
#       5          May           17
#       6          June          37
# ...

# %%
# using reset index to give a form of dataframe
timeline=df.groupby(['year','month_num','month']).count()['message'].reset_index()

# %%
timeline
# Out:
#     year  month_num      month  message
# 0   2017         11   November        1
# 1   2020          5        May      575
# 2   2020          6       June      742
# 3   2020          7       July      214
# 4   2020          8     August       93
# 5   2020          9  September      213
# 6   2020         10    October      471
# 7   2020         11   November      484
# 8   2020         12   December      143
# 9   2021          1    January      395
# 10  2021          2   February      106
# 11  2021          3      March      117
# 12  2021          4      April      202
# 13  2021          5        May      158
# 14  2021          6       June       20
# 15  2021          7       July       40
# 16  2021          8     August      102
# 17  2021          9  September       44
# 18  2021         10    October      167
# 19  2021         11   November      444
# 20  2021         12   December       92
# 21  2022          1    January       69
# ...

# %%
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i]+"-"+str(timeline['year'][i]))

# %%
timeline['time']=time

# %%
time
# Out:
# ['November-2017',
#  'May-2020',
#  'June-2020',
#  'July-2020',
#  'August-2020',
#  'September-2020',
#  'October-2020',
#  'November-2020',
#  'December-2020',
#  'January-2021',
#  'February-2021',
#  'March-2021',
#  'April-2021',
#  'May-2021',
#  'June-2021',
#  'July-2021',
#  'August-2021',
#  'September-2021',
#  'October-2021',
#  'November-2021',
#  'December-2021',
#  'January-2022',
#  'February-2022',
#  'March-2022',
#  'April-2022',
#  'May-2022',
#  'June-2022',
#  'July-2022',
#  'August-2022']

# %%
timeline
# Out:
#     year  month_num      month  message            time
# 0   2017         11   November        1   November-2017
# 1   2020          5        May      575        May-2020
# 2   2020          6       June      742       June-2020
# 3   2020          7       July      214       July-2020
# 4   2020          8     August       93     August-2020
# 5   2020          9  September      213  September-2020
# 6   2020         10    October      471    October-2020
# 7   2020         11   November      484   November-2020
# 8   2020         12   December      143   December-2020
# 9   2021          1    January      395    January-2021
# 10  2021          2   February      106   February-2021
# 11  2021          3      March      117      March-2021
# 12  2021          4      April      202      April-2021
# 13  2021          5        May      158        May-2021
# 14  2021          6       June       20       June-2021
# 15  2021          7       July       40       July-2021
# ...

# %%
plt.plot(timeline['time'],timeline['message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['only_date']=df['date'].dt.date

# %%
daily_timeline=df.groupby('only_date').count()['message'].reset_index()

# %%
plt.figure(figsize=(18,10))
plt.plot(daily_timeline['only_date'],daily_timeline['message'])

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month  day  day_name  hour  minute
# 0          5       May    7  Thursday    20      31
# 1         11  November   18  Saturday    21      55
# 2          5       May    7  Thursday    20      29
# 3          5       May    7  Thursday    20      31
# ...

# %%
df['day_name']=df['date'].dt.day_name()

# %%
df['day_name'].value_counts()
# Out:
# Friday       1092
# Sunday        874
# Monday        801
# Thursday      783
# Saturday      771
# Wednesday     680
# Tuesday       666
# Name: day_name, dtype: int64

# %%
df.head()
# Out:
#                  date                user  \
# 0 2020-05-07 20:31:00  group_notification
# 1 2017-11-18 21:55:00  group_notification
# 2 2020-05-07 20:29:00  group_notification
# 3 2020-05-07 20:31:00                  ⛰️
# 4 2020-05-07 20:34:00                 Kos
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2020-05-07  2020
# 1                 Kos created group "मित्र मण्डली"\n  2017-11-18  2017
# 2                                Sandy 1 added you\n  2020-05-07  2020
# 3                                               Bc\n  2020-05-07  2020
# 4                          Kahan chala gaya tha???\n  2020-05-07  2020
#
#    month_num     month  day  day_name  hour  minute
# 0          5       May    7  Thursday    20      31
# 1         11  November   18  Saturday    21      55
# 2          5       May    7  Thursday    20      29
# 3          5       May    7  Thursday    20      31
# ...

# %%
period=[]
for hour in df[['day_name','hour']]['hour']:
    if hour==23:
        period.append(str(hour)+"-"+str('00'))
    elif hour==0:
        period.append(str('00')+"-"+str(hour+1))
    else:
        period.append(str(hour)+"-"+str(hour+1))

# %%
df['period']=period

# %%
df.sample(5)
# Out:
#                     date     user  \
# 2359 2020-11-01 12:10:00  Sandy 1
# 5287 2022-03-15 23:08:00     Su&1
# 383  2020-05-22 20:35:00  Sandy 1
# 88   2020-05-11 11:50:00    Lala1
# 5655 2022-08-07 20:26:00       ⛰️
#
#                                            message   only_date  year  \
# 2359                    Bc hum to Kahli baithe h\n  2020-11-01  2020
# 5287  Sab apni Bndiyo ke sath lge pde hn JP Bhai\n  2022-03-15  2022
# 383                              <Media omitted>\n  2020-05-22  2020
# 88                       Mot ka samna krega vi🤣🤣\n  2020-05-11  2020
# 5655                            Ha sahi baat hai\n  2022-08-07  2022
#
#       month_num     month  day day_name  hour  minute period
# 2359         11  November    1   Sunday    12      10  12-13
# 5287          3     March   15  Tuesday    23       8  23-00
# 383           5       May   22   Friday    20      35  20-21
# 88            5       May   11   Monday    11      50  11-12
# ...

# %%
import seaborn as sns
plt.figure(figsize=(20,7))
sns.heatmap(df.pivot_table(index='day_name',columns='period',values='message',aggfunc='count').fillna(0))
plt.yticks(rotation='horizontal')
plt.show()
